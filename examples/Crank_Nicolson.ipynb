# %%
import numpy as np
import sys
sys.path.append("..")
from utils.CrankNicolson_solver import *

# %% [markdown]
# ## Heat Equation

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
U, mu = crank_heat_equation(1, .1, .1, lambda x: np.ones_like(x) * 3, 0, 1, 0, 1, filename = 'heat_solution.mp4')
# Out:
# CFL condition: a * h_t/ (h_x**2) = 9.999999999999998

# %% [markdown]
#  <video src="heat_solution.mp4" controls>

# %% [markdown]
# ## Wave Equation

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
U, mu = crank_heat_equation(1, .1, .1, lambda x: np.ones_like(x) * 3, 0, 1, 0, 1, filename = 'wave_solution.mp4')
# Out:
# CFL condition: a * h_t/ (h_x**2) = 9.999999999999998

# %% [markdown]
#  <video src="heat_solution.mp4" controls>
